# %% [markdown]
# # Classify stimulus movie clips using python convnets

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt
from time import time
import re
from os import listdir
from os.path import isfile, join
from scipy import misc
import scipy.io
from lnl_model_functions import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load labels

# %%
labels_dir = '/Users/lmcintosh/Git/deepRGC/datasets/experiment_2013_02_27/labels'
filename   = 'all.txt'

text_file = open(labels_dir + '/' + filename, "r")
spikes = text_file.read().split('\t')
#cells.append([float(spike) for spike in spikes if not ((not spike) or (spike.startswith("c")))])

text_file.close()

# %%
# labels are numCell tuples
s_prev = 0.0
eachCell = []
cells = []
for ids,s in enumerate(spikes):
    if '\r' in s:
        newSpikes = re.split('\r', s)
        if 'NAN' in newSpikes[0]:
            cells.append(eachCell)
            eachCell = []
            if newSpikes[1] == '':
                continue
            else:
                eachCell.append(float(newSpikes[1]))
        else:
            eachCell.append(float(newSpikes[0]))
            cells.append(eachCell)
            eachCell = []
            eachCell.append(float(newSpikes[1]))
    elif 'NAN' in s:
        continue
    else:
        eachCell.append(float(s))

# %%
print 'There are %d cells.' %(shape(cells)[0])
# Out:
# There are 22 cells.

# %%
longest_duration = max([max(c) for c in cells])

# %%
precision = 0.02 #0.010 # 10 ms
numBins   = int(ceil(longest_duration/precision))+1

# %%
numCells = shape(cells)[0]
labels = np.zeros((numCells, numBins))

for idc,c in enumerate(cells):
    for s in c:
        myBin = int(ceil(s/precision))
        # even if more than one spike in this bin, threshold at 1
        labels[idc, myBin] = 1

# %% [markdown]
# # Load stimulus

# %%
stimulus_dir = '/Users/lmcintosh/Git/deepRGC/datasets/experiment_2013_02_27/generate_frames/spatial_white'
filename_prefix = 'frame'
filename_suffix = '.png'

# %%
allfiles = [f for f in listdir(stimulus_dir) if isfile(join(stimulus_dir,f)) and '.png' in f]
print 'There are %d files.' %(len(allfiles))
# Out:
# There are 12500 files.

# %%
maxNumExamples = 3000

framesPerExample = 20
numExamples = min(len(allfiles) - framesPerExample + 1, maxNumExamples)
test = misc.imread(stimulus_dir + '/' + filename_prefix + str(1) + filename_suffix, flatten=True)
examples = np.zeros((numExamples, framesPerExample, test.shape[0], test.shape[1]), dtype=uint8)
for i in xrange(min(len(allfiles), maxNumExamples + framesPerExample + 1)):
    if i % 1000 == 0:
        print 'Done with %d out of %d examples.' %(i, numExamples)
    im = misc.imread(stimulus_dir + '/' + filename_prefix + str(i+1) + filename_suffix, flatten=True)
    examplesWithFrame = min(framesPerExample,i+1)
    pairs = [(ex+max(0,i-framesPerExample+1),examplesWithFrame-1-ex) for ex in xrange(examplesWithFrame) if ex+max(0,i-framesPerExample+1) < numExamples]
    for p in pairs:
        examples[p[0],p[1],:,:] = im

# %%
examples.shape
# Out:
# (3000, 20, 512, 512)

# %% [markdown]
# # Get timing information

# %%
timing_dir = '/Users/lmcintosh/Git/deepRGC/datasets/experiment_2013_02_27/labels'
stim = scipy.io.loadmat(timing_dir + '/' + '20130227T112709.mat')
stim_vars = stim['ex']
stim_vals = stim_vars[0,0]

# %%
numFrames = stim_vals['ds']['vbl'][0][0].shape[0]
startStim = stim_vals['ds']['vbl'][0][0][0,0];
startData = 0;
normalizedTime = stim_vals['ds']['vbl'][0][0] - startStim;     # frames x conditions
exptLength = max(normalizedTime.flat)/60;   # in minutes
trialLength = size(normalizedTime,0);       # in frames
frameLength = (stim_vals['ds']['vbl'][0][0][trialLength-1,0] - stim_vals['ds']['vbl'][0][0][0,0])/(trialLength-1)
#stim_vals['ds']['vbl'][0][0][1,0] - stim_vals['ds']['vbl'][0][0][0,0];  # in seconds
trialDur = trialLength*frameLength;         # in seconds
numTrials = int(round(exptLength*60/trialDur))
numTrialsPerCondition = 10

stimType = [stim_vals['pa']['stimType'][0][0][i][0][0] for i in xrange(numTrials)]

# %%
normalizedTime.shape
# Out:
# (4000, 40)

# %%
normalizedTime[2,0]
# Out:
# 0.040026985108852386

# %%
def raster(event_times_list, color='k'):
    """
    Creates a raster plot
 
    Parameters
    ----------
    event_times_list : iterable
                       a list of event time iterables
    color : string
            color of vlines
 
    Returns
    -------
    ax : an axis containing the raster plot
    """
    ax = gca()
    for ith, trial in enumerate(event_times_list):
        vlines(trial, ith + .5, ith + 1.5, color=color,linewidth=1.3)
    ylim(.5, len(event_times_list) + .5)
    
    return ax

# %%
normalizedTime[-1,1]
# Out:
# 160.09046144317836

# %%
normalizedTime.shape
# Out:
# (4000, 40)

# %%
n = 0
allTrials = []
for trial in xrange(normalizedTime.shape[1]):
    start = normalizedTime[0,trial]
    end   = normalizedTime[-1,trial]
    allTrials.append([s-start for s in cells[n] if end >= s and start <= s])

# %%
raster(allTrials)

# %%
from scipy.stats.stats import pearsonr

# %%
binsPerTrial = int(ceil(trialDur*100))

# %%
n = 20
trial1 = labels[n,:binsPerTrial]
trial2 = labels[n,binsPerTrial:2*binsPerTrial]

# %%
pearsonr(trial1,trial2)
# Out:
# (0.18201508769003286, 1.3570203439305709e-60)

# %%
plot(trial1,'k--',alpha=0.5)
plot(trial2,'r--',alpha=0.5)

# %%
np.sum(trial1==trial2)/float(len(trial1))
# Out:
# 0.99887584311766175

# %%
np.sum(np.where(trial1==1, trial2, 0))/np.sum(trial1==1)
# Out:
# 0.16666666666666666

# %%
np.sum(np.where(trial2==1, trial1, 0))/np.sum(trial2==1)
# Out:
# 0.20000000000000001

# %%
labels.shape
# Out:
# (22, 322396)

# %% [markdown]
# # Let's just look at the spatiotemporal white noise trials for now
#
# These are the first 20 trials.

# %%
normalizedTime.shape
# Out:
# (4000, 40)

# %%
shape(labels)
# Out:
# (22, 322396)

# %%
shape(labels)[1]/binsPerTrial
# Out:
# 40

# %%
n = 0
labels_aligned = np.zeros((binsPerTrial, normalizedTime.shape[1]))
for trial in xrange(normalizedTime.shape[1]):
    labels_aligned[:,trial] = labels[n, trial*binsPerTrial:(trial+1)*binsPerTrial]

# %%
tmp = labels_aligned.copy()
for t in xrange(labels_aligned.shape[1]):
    tmp[:,t] += t

# %%
plot(tmp)
# Out:
# [<matplotlib.lines.Line2D at 0x114b87350>,
#  <matplotlib.lines.Line2D at 0x114b875d0>,
#  <matplotlib.lines.Line2D at 0x114b87810>,
#  <matplotlib.lines.Line2D at 0x114b879d0>,
#  <matplotlib.lines.Line2D at 0x114b87b90>,
#  <matplotlib.lines.Line2D at 0x114b87d50>,
#  <matplotlib.lines.Line2D at 0x114b87f10>,
#  <matplotlib.lines.Line2D at 0x114b50510>,
#  <matplotlib.lines.Line2D at 0x114b8a2d0>,
#  <matplotlib.lines.Line2D at 0x114b8a490>,
#  <matplotlib.lines.Line2D at 0x114b8a650>,
#  <matplotlib.lines.Line2D at 0x114b8a810>,
#  <matplotlib.lines.Line2D at 0x114b8a9d0>,
#  <matplotlib.lines.Line2D at 0x114b8ab90>,
#  <matplotlib.lines.Line2D at 0x114b8a110>,
#  <matplotlib.lines.Line2D at 0x114b8af10>,
#  <matplotlib.lines.Line2D at 0x114b8b110>,
#  <matplotlib.lines.Line2D at 0x114b8b2d0>,
#  <matplotlib.lines.Line2D at 0x114b8b490>,
#  <matplotlib.lines.Line2D at 0x114b8b650>,
#  <matplotlib.lines.Line2D at 0x114b8b810>,
#  <matplotlib.lines.Line2D at 0x114b8ad50>,
#  <matplotlib.lines.Line2D at 0x114b8bb90>,
#  <matplotlib.lines.Line2D at 0x114b8bd50>,
#  <matplotlib.lines.Line2D at 0x114b8bf10>,
#  <matplotlib.lines.Line2D at 0x114b8d110>,
#  <matplotlib.lines.Line2D at 0x114b8d2d0>,
#  <matplotlib.lines.Line2D at 0x114b8d490>,
#  <matplotlib.lines.Line2D at 0x114b8b9d0>,
#  <matplotlib.lines.Line2D at 0x114b8d810>,
#  <matplotlib.lines.Line2D at 0x114b8da10>,
#  <matplotlib.lines.Line2D at 0x114b8db90>,
#  <matplotlib.lines.Line2D at 0x114b8dd50>,
#  <matplotlib.lines.Line2D at 0x114b8df10>,
#  <matplotlib.lines.Line2D at 0x114b8f110>,
#  <matplotlib.lines.Line2D at 0x114b8d650>,
#  <matplotlib.lines.Line2D at 0x114b8f490>,
#  <matplotlib.lines.Line2D at 0x114b8f650>,
#  <matplotlib.lines.Line2D at 0x114b8f810>,
#  <matplotlib.lines.Line2D at 0x114b8f9d0>]

# %%
labels_aligned = np.zeros((numCells, binsPerTrial, normalizedTime.shape[1]))
for n in xrange(numCells):
    for trial in xrange(normalizedTime.shape[1]):
        labels_aligned[n,:,trial] = labels[n, trial*binsPerTrial:(trial+1)*binsPerTrial]

numSpatialWhiteTrials = 20
spatialWhitePSTH = {}
for n in xrange(numCells):
    spatialWhitePSTH[n] = np.sum(labels_aligned[n,:,:numSpatialWhiteTrials], axis=1)/numSpatialWhiteTrials

# %%
plot(spatialWhitePSTH[0])

# %%
correlations = {}
for n in xrange(numCells):
    correlations[n] = np.nanmean([pearsonr(spatialWhitePSTH[n], labels_aligned[n,:,t])[0] for t in xrange(numSpatialWhiteTrials)])
# Out:
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/scipy/stats/stats.py:2436: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:607: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)

# %%
correlations[21]
# Out:
# 0.26973559953591825

# %%
thisCov = np.inner(spatialWhitePSTH[n]-np.mean(spatialWhitePSTH[n]), labels_aligned[n,:,t]-np.mean(labels_aligned[n,:,t]))/len(spatialWhitePSTH[n])

# %%
averageSTD = np.std(spatialWhitePSTH[n])

# %%
singleSTD = np.std(labels_aligned[n,:,t])

# %%
thisCov/(averageSTD*singleSTD)
# Out:
# 0.4112639669578842

# %%
plot(spatialWhitePSTH[3])

# %%
allCorrs = array(correlations.values())

# %%
allCorrs = allCorrs[~isnan(allCorrs)]

# %%
hist(allCorrs, 7, facecolor='k', alpha=0.5)
xlabel('Correlation coefficient', fontsize=16)
ylabel('Count', fontsize=16)

# %%
filt = gaussian(x=np.linspace(-.50,.50,100), sigma=.01, mu=0)

# %%
plot(filt)

# %% [markdown]
# # Try again but using Pillow strategy of smoothing first with 1ms Gaussian

# %%
labels_aligned = np.zeros((numCells, binsPerTrial, normalizedTime.shape[1]))
for n in xrange(numCells):
    for trial in xrange(normalizedTime.shape[1]):
        labels_aligned[n,:,trial] = labels[n, trial*binsPerTrial:(trial+1)*binsPerTrial]

numSpatialWhiteTrials = 20
spatialWhitePSTH = {}
for n in xrange(numCells):
    spatialWhitePSTH[n] = np.sum(labels_aligned[n,:,:numSpatialWhiteTrials], axis=1)/numSpatialWhiteTrials
    trueMean = np.mean(spatialWhitePSTH[n])
    spatialWhitePSTH[n] = np.convolve(filt, spatialWhitePSTH[n],'same')
    spatialWhitePSTH[n] *= trueMean / np.mean(spatialWhitePSTH[n])
# Out:
# -c:12: RuntimeWarning: invalid value encountered in double_scalars

# %%
plot(spatialWhitePSTH[3])

# %%
correlations = {}
for n in xrange(numCells):
    correlations[n] = np.nanmean([pearsonr(spatialWhitePSTH[n], np.convolve(filt,labels_aligned[n,:,t],mode='same'))[0] for t in xrange(numSpatialWhiteTrials)])

# %%
allCorrs = array(correlations.values())
allCorrs = allCorrs[~isnan(allCorrs)]

# %%
hist(allCorrs, 7, facecolor='k', alpha=0.5)
xlabel('Correlation coefficient', fontsize=16)
ylabel('Count', fontsize=16)

# %%
.6**2
# Out:
# 0.36

# %% [markdown]
# # Try smoothing with 10ms std Gaussian

# %%
filt = gaussian(x=np.linspace(-.50,.50,100), sigma=.1, mu=0)
plot(filt)

# %%
labels_aligned = np.zeros((numCells, binsPerTrial, normalizedTime.shape[1]))
for n in xrange(numCells):
    for trial in xrange(normalizedTime.shape[1]):
        labels_aligned[n,:,trial] = labels[n, trial*binsPerTrial:(trial+1)*binsPerTrial]

numSpatialWhiteTrials = 20
spatialWhitePSTH = {}
for n in xrange(numCells):
    spatialWhitePSTH[n] = np.sum(labels_aligned[n,:,:numSpatialWhiteTrials], axis=1)/numSpatialWhiteTrials
    trueMean = np.mean(spatialWhitePSTH[n])
    spatialWhitePSTH[n] = np.convolve(filt, spatialWhitePSTH[n],'same')
    spatialWhitePSTH[n] *= trueMean / np.mean(spatialWhitePSTH[n])

# %%
plot(spatialWhitePSTH[3])

# %%
correlations = {}
for n in xrange(numCells):
    correlations[n] = np.nanmean([pearsonr(spatialWhitePSTH[n], np.convolve(filt,labels_aligned[n,:,t],mode='same'))[0] for t in xrange(numSpatialWhiteTrials)])

# %%
allCorrs = array(correlations.values())
allCorrs = allCorrs[~isnan(allCorrs)]

# %%
hist(allCorrs, 7, facecolor='k', alpha=0.5)
xlabel('Correlation coefficient', fontsize=16)
ylabel('Count', fontsize=16)

# %%
np.max(allCorrs)
# Out:
# 0.89444414596224298

# %%
np.mean((spatialWhitePSTH[0] - np.convolve(filt,labels_aligned[0,:,0],mode='same'))**2 / (spatialWhitePSTH[0] - np.mean(spatialWhitePSTH[0]))**2)
# Out:
# 62674241.252134606

# %%
tmp = np.convolve(filt,labels_aligned[0,:,0],mode='same')

# %%
np.mean(tmp)
# Out:
# 0.44398877961097571

# %%
np.mean(spatialWhitePSTH[0])
# Out:
# 0.0030539595303522168

# %%
np.var((spatialWhitePSTH[0] - tmp))
# Out:
# 5.8874764310357692

# %%
np.std(spatialWhitePSTH[0])
# Out:
# 0.0085302799908387218

# %%
np.var((spatialWhitePSTH[0] - tmp)) / (np.std(spatialWhitePSTH[0]) * np.std(tmp))
# Out:
# 283.97556009276803

# %%
n = 3
t = 8

tmp1 = spatialWhitePSTH[n]/np.var(spatialWhitePSTH[n])
tmp1 -= np.mean(tmp1)

tmp2 = np.convolve(filt,labels_aligned[n,:,t],mode='same')
tmp2 /= np.var(tmp2)
tmp2 -= np.mean(tmp2)

print (pearsonr(tmp1,tmp2), 1 - np.var((tmp1 - tmp2)/tmp1))
# Out:
# ((0.83008089644629668, 0.0), -1.4367578698865282)

# %%
1 - np.var((tmp1 - tmp2)**2/(tmp1-np.mean(tmp1))**2)
# Out:
# -48781.05832750952

# %% [markdown]
# # Train a network!

# %%
from utils.classifiers.convnet import init_five_layer_convnet
from utils.classifiers.convnet import five_layer_convnet

# %%
convnet = init_five_layer_convnet(input_shape=(20,512,512), num_classes=2, filter_sizes=(5,5,5), 
                                  num_filters=(32,32,64,128))

# %%
# Divide examples into training, validation, and test sets
trainMask = np.random.choice(examples.shape[0], size=examples.shape[0]/2, replace=False)
valMask   = np.random.choice(examples.shape[0], size=examples.shape[0]/4, replace=False)
testMask  = np.random.choice(examples.shape[0], size=examples.shape[0]/4, replace=False)

X_train = examples[trainMask]
X_val   = examples[valMask]
X_test  = examples[testMask]

# Zero-mean the data
mean_img = np.mean(X_train, axis=0)
X_train -= mean_img
X_val -= mean_img
X_test -= mean_img

# %%
# for now choose a neuron
n = 0

# move labels into same space as X
# the following works only when label precision is same as X
y = labels[n, framesPerExample:(numExamples+framesPerExample)]

y_train = y[trainMask]
y_val   = y[valMask]
y_test  = y[testMask]

# %%
from utils.classifier_trainer import ClassifierTrainer

model_copy = convnet
trainer = ClassifierTrainer()
learning_rate = 1e-2
reg = 1e-3
dropout = 1.0
num_epochs = 1

# choose best learning rate from cross validation with 1 epoch
#lr_hist = {} # for lr in logspace(-6,-2,10):
#lr = lr_hist.keys()[np.argmax(lr_hist.values())] # lr of 0.00016681005372000591 for 0.2425 val acc

# choose best regularization from cross validation with 1 epoch
#r_hist = {} # for r in logspace(-5,-1,10)
#r = r_hist.keys()[np.argmax(r_hist.values())] # r of 0.00016681005372000591 for 0.2425 val acc


best_model = None
best_val_acc = 0

#for r in logspace(-5,-1,10):
finetuned_model, loss_history, train_acc_history, val_acc_history = trainer.train(X_train, y_train, X_val, y_val,
                                model_copy, five_layer_convnet,
                                learning_rate=learning_rate, reg=reg, update='rmsprop',
                                dropout=dropout, num_epochs=num_epochs, verbose=True)
#print 'Validation accuracy %s for learning rate %s.' %(np.max(val_acc_history), lr)
print 'Validation accuracy %s for regularization %s.' %(np.max(val_acc_history), r)

if np.max(val_acc_history) > best_val_acc:
    best_model = finetuned_model
    best_val_acc = np.max(val_acc_history)

#lr_hist[lr] = np.max(val_acc_history)
#r_hist[r] = np.max(val_acc_history)
